# %% [markdown]
# # Ian Murphy
# # BrainStation, Capstone EDA
# # 12/10/2020

# %% [markdown]
# ### Data Dictionary
#
# (included in previous notebook, but adding here as well for ease of use)
#
# This cell contains a Data Dictionary containing the description for every feature the the dataframe called 'outcomes_df':
#
# PER: This stands for Player Efficiency Rating. This is a measure of a player's per-minute productivity. It takes into account all of the positive things a player does, and creates a metric to measure how productive that player is. It is mean to summarize a player's statistical accomplishments in a single number.
#
# TSP: This stands for True Shooting Percentage. True shooting percentage is a measure of shooting efficiency that takes into account 2 point field goals, 3-point field goals, and free throws.
#
# PER and TSP will be included for the top 12 players on each team. (top 12 by minutes played per game). For example Player1_PER is the PER for the player on that team that played the most minutes per game that season.
#
# AVG_PER: This is the average Player Efficiency Rating of the top 12 players on each team.
#
# AVG_TSP: This is the average True Shooting Percentage of the top 12 players on each team.
#
# Coaches: I will be using dummy variables for coaches. The column titles will be the first initial, and then the last name the coach for each respective season. If the value is 1 then that means that respective coach was the coach of that team that season. If the value is 0, then that coach was not coaching that team, that season.
#
# ORtg: This stands for Offensive Rating. It is points scored per 100 possessions by a team.
#
# Rel ORtg:This is similar to ORtg, but it is relative to the league average.
#
# DRtg: This stands for Defensive Rating. It is the amount of points allowed per 100 posessions by a team.
#
# Rel DRtg: This is similar to DRtg, but it is relative to the league average.
#
# SRS: This stands for Simple Rating System. This rating takes into account average point differential and strength of schedule. The rating is denominated in points above or below the average, where zero is average.
#
# Pace: The Pace factor is an estimate of the number of possessions per 48 minutes by a team.
#
# Rel Pace: This is similar to Pace, but it is relative to the league average.
#
# Playoffs: This is the target variable. 0 means the team did not make the playoffs that year. 1 Means the team did make the playoffs that year.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
outcomes_df = pd.read_csv('data/outcomes_df.csv')

# %%
outcomes_df.head()
# Out:
#    Unnamed: 0 Team  Year  player1_PER  player2_PER  player3_PER  player4_PER  \
# 0           0  NYK  2020         17.5         10.7         23.5         14.6
# 1           1  NYK  2019          8.7         10.8         13.9         14.6
# 2           2  NYK  2018         13.0         14.4         24.0          7.0
# 3           3  NYK  2017         17.9         12.2         17.4         17.0
# 4           4  NYK  2016         20.3         10.9         17.6         17.7
#
#    player5_PER  player6_PER  player7_PER  ...  T. Porter   T. Stotts   \
# 0         16.5         16.0          9.8  ...           0           0
# 1         14.4         12.2         22.0  ...           0           0
# 2         17.8         20.4         11.5  ...           0           0
# 3         12.7         12.7         19.0  ...           0           0
# 4         11.7         12.3         17.2  ...           0           0
#
#    T. Thibodeau   V. Del Negro   W. Unseld   Division  AVG_PER   AVG_TSP  \
# 0              0              0           0         0  14.6125  0.536500
# 1              0              0           0         0  13.4250  0.547125
# 2              0              0           0         0  16.0125  0.546625
# 3              0              0           0         0  16.1750  0.542875
# 4              0              0           0         0  14.7625  0.540125
#
#        Location  Playoffs
# 0  New York, NY         0
# 1  New York, NY         0
# 2  New York, NY         0
# 3  New York, NY         0
# 4  New York, NY         0
#
# [5 rows x 191 columns]

# %% [markdown]
# ### Basic EDA
#
# Showing shape, nulls, duplicates.

# %%
outcomes_df.shape
# Out:
# (876, 191)

# %%
outcomes_df.isna().sum().sum()
# Out:
# 0

# %%
outcomes_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# It looks like my data set is ready for more in depth analysis. I am going to dive into the specific features and examine correlation and multicollinearity.

# %% [markdown]
# ### Correlation Heat Map
#
# Creating heat map for the following features: ‘AVG PER’, ‘AVG TSP’, ‘Pace’, ‘Rel Pace’, 'SRS', 'Pace', 'Rel Pace', 'ORtg', 'DRtg', 'Rel ORtg', 'Rel DRtg', ‘Playoffs’.
#
# Since I have so many features, I am not going to print out every single one, but rather select a few key statistics that I suspect may be correlated to eachother.
#
# My data set is not too large so I will be trying a number of different dimension reduction techniques, and testing them out on different models. I will investegate using the heatmap. Then move on to calculating VIF scores. I will also perform PCA in my modeling notebook.

# %%
# selecting a few key features to make a heat map. Need to put the selected features into a dataframe 
# I am using AVG_PER and AVG_TSP and all of the team stats. I'm leaving out coaches and individual player stats 
corr_df =  outcomes_df[['AVG_PER', 'AVG_TSP', 'player1_PER', 'Pace', 'Rel Pace', 'SRS', 'ORtg', 'DRtg', 'Rel ORtg', 'Rel DRtg', 'Playoffs']]

# %%
# showing the heatmap 
corr_df.corr().style.background_gradient(cmap="coolwarm", vmin=-1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col0,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col1,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col2,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col3,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col4,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow5_col5,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow6_col6,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow7_col7,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow8_col8,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow9_col9,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow10_col10{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col1,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col0{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col2,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col0{
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col3,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col0{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col4,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col0,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col6,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow6_col4{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col5,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow5_col0{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col6,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow6_col0{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col7,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow7_col0,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow8_col9,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow9_col8{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col8,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow8_col0{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col9,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow9_col0{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow0_col10,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col5,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow5_col1,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow10_col0{
#             background-color:  #f29274;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col2,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col1,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col9,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow9_col4{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col3,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col1{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col4,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col1{
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col6,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow5_col8,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow6_col1,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow8_col5{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col7,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow7_col1{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col8,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col4,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col3,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow8_col1{
#             background-color:  #ec7f63;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col9,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow9_col1{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow1_col10,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col6,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow6_col2,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow10_col1{
#             background-color:  #f7af91;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col3,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col2{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col4,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col2{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col5,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col7,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow5_col2,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow7_col3{
#             background-color:  #f6a283;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col7,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow7_col2{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col8,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow8_col2{
#             background-color:  #f5a081;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col9,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow9_col2{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow2_col10,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow10_col2{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col5,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow5_col3{
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col6,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow6_col3{
#             background-color:  #f7b599;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col8,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow8_col3{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col9,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow9_col3{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow3_col10,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow10_col3{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col5,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow5_col4{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col7,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow7_col4{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col8,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow8_col4{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow4_col10,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow10_col4{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow5_col6,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow6_col5{
#             background-color:  #e57058;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow5_col7,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow7_col5{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow5_col9,#T_f7a743a4_408d_11eb_b3e8_58961df8e9dfrow9_col5{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_f7a743a4

# %% [markdown]
# There are a few features that have strong correlations with eachother. Some make sense, some are suprising.
# - 'Pace' and 'Rel Pace'. This makes sense as they are measuring the same basic statistic. Pace is a measure of how fast a team plays in terms of going up and down the court. 'Rel Pace' is just the same stat relative to the league average.
# - The same goes for 'ORtg', 'Rel ORtg',	'DRtg',	'Rel DRtg' respectively. I may need to drop the relative features because they are repetitive.
# - 'ORtg' and 'Rel ORtg' have a strong correlation with AVG_TSP. This makes sense because these are measures of offensive production. The more productive a teamis on offense will certainly correlate with their shooting percentage (TSP)
# - 'SRS' has the strongest correlation with making the playoffs. This makes a lot of sense because SRS (Simple Rating System) is an overall team stat the measures how well the team is performing on both ends of the floor. SRS takes into account strength of schedule and average point differential.
# - 'Player1_PER' has a positive correlation, but it is not that strong. I would gess this would be one of the strongest, but perhaps the overall team aVG PER is more important as shown in this heatmap.

# %% [markdown]
# ### Variance Inflation Factor
#
# I am going to use the VIF method to dive in deeper into the features. I want to examine the amount of amount of multicollinearity and see if there are any columns that I can drop to reduce the VIF scores of the other variables.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

pd.Series([variance_inflation_factor(corr_df.values, i) 
               for i in range(corr_df.shape[1])], 
              index=corr_df.columns)
# Out:
# C:\Users\ifmur\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# AVG_PER         722.185284
# AVG_TSP        1837.658057
# player1_PER      25.537727
# Pace           2174.130732
# Rel Pace          2.482645
# SRS             135.155134
# ORtg                   inf
# DRtg                   inf
# Rel ORtg               inf
# Rel DRtg               inf
# Playoffs          5.831482
# dtype: float64

# %% [markdown]
# There are a number of very high scores. This is what I expected because in sports, almost every stat is tied together in one way or another. My first thought is to remove Rel Ortg, Rel Drtg, and Pace. I do not want to remove ORtg and DRtg as they are really important statistics and measure offensive and defensive performance. My goal is to remove as much colinearity as I can with out loosing vital information. I will not be able to remove all the multicolinearity because of the nature of my project.
#
# Relative stats are the same measure, but relative to the league average. They have a lot of multicolinearity because of that, and I think that is causing the VIF scores to rise.

# %%
corr_df_new = corr_df.drop(['Rel ORtg', 'Rel DRtg', 'Pace'], axis =1)

# %%
pd.Series([variance_inflation_factor(corr_df_new.values, i) 
               for i in range(corr_df_new.shape[1])], 
              index=corr_df_new.columns)
# Out:
# AVG_PER          674.485054
# AVG_TSP         1714.957794
# player1_PER       25.188084
# Rel Pace           1.037621
# SRS              132.879312
# ORtg           64909.757498
# DRtg           62758.105581
# Playoffs           5.769091
# dtype: float64

# %% [markdown]
# I did see a slight decrease in almost every category. I want to use the entire data set and look at those VIF scores. I will pu them in a dictionary and sort them to make it easier to read and plot in a visual.

# %%
new_outcomes_df = outcomes_df.drop(['Team', 'Year', 'Location'], axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vifs = pd.Series([variance_inflation_factor(new_outcomes_df.values, i) 
           for i in range(new_outcomes_df.shape[1])], 
          index=new_outcomes_df.columns)
# Out:
# C:\Users\ifmur\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
vifs_dict = dict(vifs)

# %%
sorted_vifs_dict = sorted(vifs_dict.items(), key=lambda kv: kv[1])

# %%
sorted_vifs_dict[:-10]
# Out:
# [('playe11_PER', 2.277788249648934),
#  ('player10_TSP', 2.2929767943285113),
#  ('player9_PER', 2.325077421337637),
#  ('player9_TSP', 2.3344878494079517),
#  ('player10_PER', 2.3504427030837216),
#  ('player11_TSP', 2.3579757780142145),
#  ('player12_PER', 2.8352159846556355),
#  ('player12_TSP', 3.034993328403722),
#  ('Playoffs', 3.383654643422511),
#  ('Rel Pace', 4.989669064492156),
#  ('Division', 6.22669449796834),
#  ('Pace', 6.250857525185122),
#  ('Unnamed: 0', 7.508066312614935),
#  ('L. Hamilton ', 8.025359655159258),
#  ('R. Ayers ', 8.062329211620202),
#  ('G. Irvine ', 8.064318912571839),
#  ("K. O'Neill ", 8.084473896321276),
#  ('G. Heard ', 8.100660077494709),
#  ('B. Hanzlik ', 8.397684343431138),
#  ('D. Versace ', 8.437212205555149),
#  ('Q. Buckner ', 8.493657026393942),
#  ('F. Carter ', 8.546692262796006),
#  ('S. Vincent ', 8.562171230390225),
#  ('S. Jackson ', 8.566612592186473),
#  ('G. Littles ', 8.568999517383835),
#  ('M. Dunlap ', 8.575493402583232),
#  ('M. Curry ', 8.616189199201282),
#  ('J. Tarkanian ', 8.626430474169922),
#  ('J. Beilein ', 8.641980196082589),
#  ('L. Krystkowiak ', 8.646775313322385),
#  ('D. Moe ', 8.652099487685614),
#  ('B. Malone ', 8.675762003221239),
#  ('B. Musselman ', 8.754296601738652),
#  ('J. Boylen ', 8.757410159427629),
#  ('R. Saunders ', 8.898054707479556),
#  ('T. Jenkins ', 8.911490839122905),
#  ('J. Bickerstaff ', 8.916312473994886),
#  ('I. Kokoskov ', 9.22806956298603),
#  ('B. Cartwright ', 15.133199995164913),
#  ('F. Johnson ', 15.172466061444869),
#  ('B. Carter ', 15.377891259293678),
#  ('B. Shaw ', 15.726227440253627),
#  ('H. Brown ', 15.804750771576735),
#  ('D. Fisher ', 15.818189641189969),
#  ('D. Blatt ', 15.825966430974306),
#  ('R. Theus ', 15.87643439187427),
#  ('J. Davis ', 15.878559594932934),
#  ('M. Montgomery ', 15.938210543621034),
#  ('K. Smart ', 15.944335458441905),
#  ('K. Rambis ', 15.951702773666804),
#  ('R. Rothstein ', 15.990800726493841),
#  ('D. Walker ', 16.02905919002216),
#  ('J. Rodgers ', 16.104088235785735),
#  ('M. Carr ', 16.113960494437535),
#  ('J. Triano ', 16.13016337443758),
#  ('M. Iavaroni ', 16.1543907361547),
#  ('E. Watson ', 16.178123094119172),
#  ('R. Pfund ', 16.19512758373408),
#  ('K. Jones ', 16.208174674681516),
#  ('B. Winters ', 16.223075133290926),
#  ('B. Blair ', 16.225669635170927),
#  ('J. Cleamons ', 16.23785443257106),
#  ('M. Schuler ', 16.363210071577384),
#  ('J. Kuester ', 16.36772059427748),
#  ('J. Borrego ', 16.508969648735253),
#  ('L. Pierce ', 16.645063332919396),
#  ('N. Nurse ', 16.64753178791089),
#  ('B. Beard ', 16.662653965909264),
#  ('P. Westhead ', 16.735485887455276),
#  ('L. Kruger ', 22.247320967075467),
#  ('L. Bird ', 22.306306143692037),
#  ('E. Musselman ', 22.644382189091516),
#  ('M. Guokas ', 22.67773105279063),
#  ('J. Bzdelik ', 22.79250420942478),
#  ('M. Jackson ', 22.825053241865138),
#  ('D. Ainge ', 22.89916826521233),
#  ('T. Porter ', 23.210499994769428),
#  ('J. Vaughn ', 23.40143507179736),
#  ('J. Calipari ', 23.49823843315459),
#  ('T. Corbin ', 23.614906011571836),
#  ('R. Adubato ', 23.73337115845313),
#  ('C. Fitzsimmons ', 23.805095450155672),
#  ('T. Lue ', 24.03818135386056),
#  ('R. Pitino ', 29.261059384215496),
#  ('S. Lowe ', 29.98369366005924),
#  ('K. Loughery ', 30.471558374702575),
#  ('L. Drew ', 30.744830756412334),
#  ('K. Atkinson ', 30.998912783475763),
#  ('W. Unseld ', 31.130048165117756),
#  ('L. Walton ', 31.447650299238806),
#  ('D. Motta ', 31.710471333764207),
#  ('D. Fizdale ', 31.735651519046883),
#  ('F. Hoiberg ', 32.181896434802496),
#  ('T. Floyd ', 36.580491603956766),
#  ('D. Cowens ', 36.92511501348822),
#  ('K. McHale ', 37.28975683827505),
#  ('I. Thomas ', 37.40252137262736),
#  ('G. St. Jean ', 38.004253137420285),
#  ('A. Bristow ', 38.20608034913905),
#  ('J. Lucas ', 38.433133312796954),
#  ('J. Hornacek ', 38.695883763355944),
#  ('V. Del Negro ', 38.702451456860985),
#  ('J. Kidd ', 38.8191489926224),
#  ('J. Lynam ', 39.02760216211262),
#  ('B. Weiss ', 39.032667948486264),
#  ('B. Donovan ', 40.144027047911656),
#  ('D. Chaney ', 44.97596631712003),
#  ('D. Issel ', 45.268485350287705),
#  ('C. Daly ', 45.515904912598806),
#  ('L. Hollins ', 45.90453494143544),
#  ('S. Mitchell ', 46.30484143401278),
#  ('A. Johnson ', 46.334628356544066),
#  ('Q. Snyder ', 46.39866420845002),
#  ('B. Fitch ', 46.70974881619571),
#  ('M. Williams ', 46.86460575572714),
#  ('D. Joerger ', 47.10773306205868),
#  ('S. Kerr ', 47.26894551330871),
#  ('P. Silas ', 52.22273368451572),
#  ('B. Bickerstaff ', 52.95448019917365),
#  ('B. Brown ', 53.43800604632475),
#  ('B. Stevens ', 53.94563108499446),
#  ('D. Harris ', 53.97626554204667),
#  ('S. Clifford ', 54.32219850827286),
#  ('M. Malone ', 54.43277547067414),
#  ('M. Budenholzer ', 54.667105363625346),
#  ("J. O'Brien ", 59.207110776721365),
#  ('R. Wittman ', 59.78733332782838),
#  ('M. Fratello ', 60.09895063853918),
#  ('D. Collins ', 60.183576438997434),
#  ('L. Frank ', 60.19966176550971),
#  ('P. Carlesimo ', 60.90692745201444),
#  ('F. Vogel ', 60.9386675484586),
#  ('M. Woodson ', 61.00289396354043),
#  ('M. Brown ', 61.134019833567436),
#  ('E. Jordan ', 61.15277482943362),
#  ('T. Thibodeau ', 61.598162818817386),
#  ('C. Ford ', 67.80421462454073),
#  ('M. Cheeks ', 67.95728422656903),
#  ('J. Van Gundy ', 71.809664996643),
#  ('P. Westphal ', 75.75327805691691),
#  ('S. Brooks ', 77.13326081156482),
#  ('T. Stotts ', 82.51725818341752),
#  ('S. Van Gundy ', 88.86187308442315),
#  ('S. Skiles ', 89.39776256603902),
#  ('R. Tomjanovich ', 89.39948703685728),
#  ('D. Casey ', 91.24432805250935),
#  ('E. Spoelstra ', 92.36888141438804),
#  ('P. Riley ', 103.0219060213865),
#  ("M. D'Antoni ", 104.99119203991637),
#  ('L. Wilkens ', 105.10483969932525),
#  ('A. Gentry ', 105.29129763386923),
#  ('B. Hill ', 111.9194868614505),
#  ('B. Scott ', 112.58558699427311),
#  ('N. McMillan ', 113.97162753004214),
#  ('F. Saunders ', 120.35684057062687),
#  ('M. Dunleavy ', 126.9949142566649),
#  ('D. Nelson ', 127.2035520408278),
#  ('R. Carlisle ', 135.15678542423427),
#  ('L. Brown ', 141.5742634862551),
#  ('P. Jackson ', 143.23386705107913),
#  ('G. Karl ', 149.64276039983176),
#  ('J. Sloan ', 155.81704413476268),
#  ('R. Adelman ', 156.0573816510185),
#  ('D. Rivers ', 156.53033301212264),
#  ('G. Popovich ', 174.73772030515048),
#  ('SRS', 243.3171599405007),
#  ('player1_PER', inf),
#  ('player2_PER', inf),
#  ('player3_PER', inf),
#  ('player4_PER', inf),
#  ('player5_PER', inf),
#  ('player6_PER', inf),
#  ('player7_PER', inf),
#  ('player8_PER', inf),
#  ('player1_TSP', inf),
#  ('player2_TSP', inf),
#  ('player3_TSP', inf),
#  ('player4_TSP', inf)]

# %% [markdown]
# Just glossing over the scores quickly. They look much better when looking at them as a whole. There are a number of player stats that are infinity, which is not ideal, but I do not want to loose that information because I feel it is vital to answeting my question. (What stats are the most important). If i drop the player stats, I wont be able to answer questions like 'does player 1 have more impact then player 5?' This was one of my main goals in the project, so I need to keep these in my modeling.
#
# 'SRS' is another stat that has high VIF score, but I dont think I can drop it as it has the strongest correlation to outcome.

# %% [markdown]
# I will move on to modeling and use PCA for dimension reduction. I don't feel it is worth it to remove key features even if they have a high VIF score.
